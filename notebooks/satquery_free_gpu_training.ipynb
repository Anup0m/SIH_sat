# %% [markdown]
# # 🛰️ SatQuery AI — Free GPU Training Notebook (Colab / Kaggle)
# ### Multimodal Remote Sensing Vision-Language Assistant (SIH26167)
# Use this notebook to train on **free GPUs (Google Colab T4 or Kaggle Dual T4)** if you want to complete training before entering the college lab!

# %%
# Step 1: Check GPU Acceleration
# !nvidia-smi

# %%
# Step 2: Install Required Libraries
# !pip install -q pyarrow datasets huggingface_hub pyyaml pydantic fastapi uvicorn

# %%
# Step 3: Run Hardware Diagnostics & Baseline Evaluation
# !python training/launcher.py --task eval

# %%
# Step 4: Run Remote-Sensing VLM Adaptation on BigEarthNet.txt (LoRA)
# Checkpoint and resume support is enabled automatically!
# !python training/launcher.py --task vlm

# %%
# Step 5: Run Bi-Temporal Siamese Change Detection Training
# !python training/launcher.py --task change

# %%
# Step 6: Package Trained Checkpoints for Download
# !zip -r satquery_checkpoints.zip checkpoints/
from google.colab import files
files.download('satquery_checkpoints.zip')
print('[✓] Checkpoints ready to transfer back to your local laptop!')
